# %% [markdown]
# ## Plotting basics
#  - Use [this tutorial](https://matplotlib.org/users/pyplot_tutorial.html) as reference when (if) you get stuck
#  - Execute the cells with imports, otherwise you won't have numpy and matplotlib imported and Python will complain

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
# Load weather data (take a look at that CSV file on GitHub or via Excel and note column names)
weather = np.loadtxt("OshawaWeather2016.csv", skiprows=1, delimiter=',')

# %% [markdown]
# #### Crate separate 1D arrays for each column (e.g: day, maxt, mint and so on)

# %%
data = pd.read_csv('OshawaWeather2016.csv')
data
# Out:
#      Day  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  Total Precip (mm)
# 0      0            0.0           -2.0            -1.0                0.0
# 1      1            2.0           -4.0            -1.0                0.0
# 2      2            2.0           -2.0             0.0                0.0
# 3      3           15.0          -15.0             0.0                0.0
# 4      4           -1.0          -16.0            -8.5                0.0
# 5      5            2.5           -7.0            -2.3                0.0
# 6      6            4.0           -6.0            -1.0                0.0
# 7      7            6.0           -3.0             1.5                0.0
# 8      8            7.0            2.0             4.5               29.8
# 9      9            7.0            5.0             6.0               12.8
# 10    10           -2.5           -7.0            -4.8                3.5
# 11    11            0.0           -9.0            -4.5                5.0
# 12    12           -5.0          -11.0            -8.0                2.0
# 13    13           -0.5           -8.0            -4.3                0.5
# 14    14            4.5           -3.5             0.5                9.4
# 15    15            3.5            0.0             1.8                0.0
# 16    16            0.0           -3.0            -1.5                0.0
# 17    17           -7.0          -12.0            -9.5                0.0
# 18    18           -3.0          -15.0            -9.0                0.0
# 19    19           -2.0           -5.5            -3.8                0.0
# 20    20           -3.0           -6.0            -4.5                0.0
# 21    21           -2.0          -10.0            -6.0                0.0
# 22    22           -5.0          -12.0            -8.5                0.0
# 23    23            2.0          -12.0            -5.0                0.0
# 24    24            5.5           -2.0             1.8                1.0
# 25    25            6.0            2.0             4.0                0.7
# 26    26            2.0           -3.0            -0.5                1.0
# 27    27            2.0           -1.0             0.5                1.0
# 28    28            0.0           -9.0            -4.5                0.0
# 29    29            5.0           -8.0            -1.5                0.0
# ..   ...            ...            ...             ...                ...
# 319  336            5.0            3.0             4.0                0.2
# 320  337            5.0            0.0             2.5                0.0
# 321  338            3.0           -4.0            -0.5                8.2
# 322  339            7.0           -1.0             3.0                0.0
# 323  340            5.0           -1.5             1.8                6.8
# 324  341            4.0            2.0             3.0                0.6
# 325  342            1.0            0.0             0.5                1.0
# 326  343           -1.0           -7.0            -4.0                0.0
# 327  344           -3.0           -5.0            -4.0                1.0
# 328  345            2.0           -7.0            -2.5                9.0
# 329  346            4.0           -2.0             1.0                0.0
# 330  347            1.0           -2.0            -0.5                0.0
# 331  348           -3.5           -8.0            -5.8                0.0
# 332  349           -7.0          -12.5            -9.8                7.0
# 333  350           -2.5          -14.0            -8.3                9.0
# 334  351            0.5           -7.0            -3.3                1.0
# 335  352           -2.5           -5.0            -3.8                0.0
# 336  353           -1.0          -13.5            -7.3                0.0
# 337  354            2.0           -9.0            -3.5                0.0
# 338  355            2.5           -3.0            -0.3                1.0
# 339  356            4.0           -0.5             1.8                0.0
# 340  357            3.5           -1.0             1.3                0.0
# 341  358            5.0            1.0             3.0                0.0
# 342  359            2.0            0.0             1.0                1.4
# 343  360            9.5           -6.5             1.5               17.2
# 344  361            2.0            0.0             1.0                0.0
# 345  362            2.0           -3.0            -0.5                2.0
# 346  363            3.0           -1.0             1.0                0.0
# 347  364            2.0           -3.0            -0.5                1.0
# 348  365            5.0           -3.5             0.8                0.0
#
# [349 rows x 5 columns]

# %% [markdown]
# #### Plot the minimum temperature as a function of day number

# %%
x = data.Day
y = data.Min Temp(°C)
x,y
# Out:
#   File "<ipython-input-37-f8aef71bdfca>", line 2
#     y = data.Min Temp(°C)
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Plot the max temperature in degrees Fahrenheit

# %% [markdown]
# #### Plot the difference between the maximum and the minimum day temperature as a function of day number

# %% [markdown]
# #### Plot both, the minimum and maximum temperature on the same plot

# %% [markdown]
# #### Read about the following functions to add axis labels and a legend to the plot above
#  - plt.xlabel
#  - plt.ylabel
#  - plt.title
#  - plt.legend

# %% [markdown]
# #### Read aboun plt.hist() function to plot a histogram of the maximum temperatures

# %%
plt.hist
